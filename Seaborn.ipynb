# %%
import seaborn as sns
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#tips = sns.load_dataset('grocery.csv')
iris = pd.read_csv('iris.csv')
data1 = pd.read_csv('Data.csv')

# %%
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
data1
# Out:
#     ID      Age  Income  Gender Marital Status Buys
# 0    1     < 21    High    Male         Single   No
# 1    2     < 21    High    Male        Married   No
# 2    3  21 - 35    High    Male         Single  Yes
# 3    4     > 35  Medium    Male         Single  Yes
# 4    5     > 35     Low  Female         Single  Yes
# 5    6     > 35     Low  Female        Married   No
# 6    7  21 - 35     Low  Female        Married  Yes
# 7    8     < 21  Medium    Male         Single   No
# 8    9     < 21     Low  Female        Married  Yes
# 9   10     > 35  Medium  Female         Single  Yes
# 10  11     < 21  Medium  Female        Married  Yes
# 11  12  21 - 35  Medium    Male        Married  Yes
# 12  13  21 - 35    High  Female         Single  Yes
# 13  14     > 35  Medium    Male        Married   No

# %% [markdown]
# ### Categorical Plots

# %%
sns.distplot(iris['sepal.length'],bins=30)
# Out:
# /Users/mlondi/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal.length', ylabel='Density'>

# %%
sns.jointplot(x='sepal.length',y='sepal.width',data = iris,kind='hex')

# %%
sns.pairplot(data=iris,hue='variety',palette='coolwarm')

# %%
sns.rugplot(iris['sepal.length'])
# Out:
# <AxesSubplot:xlabel='sepal.length'>

# %% [markdown]
# ### Categorical Plots

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.barplot(x='variety',y='sepal.width',data=iris,estimator=np.std)
# Out:
# <AxesSubplot:xlabel='variety', ylabel='sepal.width'>

# %%
sns.countplot(data = data1,x='Buys')
# Out:
# <AxesSubplot:xlabel='Buys', ylabel='count'>

# %%
sns.boxplot(x='variety',y='sepal.length',data=iris)
# Out:
# <AxesSubplot:xlabel='variety', ylabel='sepal.length'>

# %%
sns.violinplot(x='variety',y='sepal.length',data=iris)
# Out:
# <AxesSubplot:xlabel='variety', ylabel='sepal.length'>

# %%
sns.stripplot(x='variety',y='sepal.length',data=iris,jitter=True)
#sns.violinplot(x='variety',y='sepal.length',data=data)
# Out:
# <AxesSubplot:xlabel='variety', ylabel='sepal.length'>

# %%
sns.swarmplot(x='variety',y='sepal.length',data=iris,color='black')
sns.violinplot(x='variety',y='sepal.length',data=iris)
# Out:
# <AxesSubplot:xlabel='variety', ylabel='sepal.length'>

# %% [markdown]
# ### Matrix Plots

# %%
ma = iris.corr()
ma
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(data = ma, annot=True)
# Out:
# <AxesSubplot:>

# %%
data2 = pd.read_csv('SalesRecords.csv')
data2.head()
# Out:
#                               Region                Country      Item Type  \
# 0       Middle East and North Africa             Azerbaijan         Snacks
# 1  Central America and the Caribbean                 Panama      Cosmetics
# 2                 Sub-Saharan Africa  Sao Tome and Principe         Fruits
# 3                 Sub-Saharan Africa  Sao Tome and Principe  Personal Care
# 4  Central America and the Caribbean                 Belize      Household
#
#   Sales Channel Order Priority Order Date   Order ID   Ship Date  Units Sold  \
# 0        Online              C  10/8/2014  535113847  10/23/2014         934
# 1       Offline              L  2/22/2015  874708545   2/27/2015        4551
# 2       Offline              M  12/9/2015  854349935   1/18/2016        9986
# 3        Online              M  9/17/2014  892836844  10/12/2014        9118
# 4       Offline              H   2/4/2010  129280602    3/5/2010        5858
#
# ...

# %%
d2 = data2.corr()
sns.heatmap(data = d2, annot = False)
# Out:
# <AxesSubplot:>

# %%
sls = data2.pivot_table(index='Item Type',columns='Region',values='Total Profit')
sls
# Out:
# Region                    Asia  Australia and Oceania  \
# Item Type
# Baby Food        469157.611942          471029.061437
# Beverages         75807.095501           79130.233324
# Cereal           449103.424897          438029.352084
# Clothes          372213.938028          380493.536977
# Cosmetics        870838.816482          870210.307727
# Fruits            12083.551409           11963.094477
# Household        836096.616540          830501.030046
# Meat             285914.223656          283602.994611
# Office Supplies  614604.170928          642816.682099
# Personal Care    126049.059716          128717.771080
# Snacks           283090.682968          278434.625562
# Vegetables       322321.192986          318249.119167
#
# Region           Central America and the Caribbean         Europe  \
# Item Type
# Baby Food                            486199.770673  472724.992890
# Beverages                             79286.042471   80255.624373
# ...

# %%
sns.heatmap(data = sls, linecolor='white',linewidths=0.5)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Item Type'>

# %%
sns.clustermap(data = sls,cmap='coolwarm')

# %% [markdown]
# ### Grids

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris['variety'].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
g = sns.PairGrid(iris)

g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
g.map_diag(sns.distplot)
# Out:
# /Users/mlondi/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/mlondi/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Regression Plots

# %%
hour = pd.read_csv('hours.csv')
hour
# Out:
#    Number of hours spent driving  Risk Score on a scale of 0-100
# 0                             10                              95
# 1                              9                              80
# 2                              2                              10
# 3                             15                              50
# 4                             10                              45
# 5                             16                              98
# 6                             11                              38
# 7                             16                              93

# %%
sns.lmplot(data=hour, x='Number of hours spent driving', y ='Risk Score on a scale of 0-100')

# %% [markdown]
# ### Style and Color

# %%
data2.head()
# Out:
#                               Region                Country      Item Type  \
# 0       Middle East and North Africa             Azerbaijan         Snacks
# 1  Central America and the Caribbean                 Panama      Cosmetics
# 2                 Sub-Saharan Africa  Sao Tome and Principe         Fruits
# 3                 Sub-Saharan Africa  Sao Tome and Principe  Personal Care
# 4  Central America and the Caribbean                 Belize      Household
#
#   Sales Channel Order Priority Order Date   Order ID   Ship Date  Units Sold  \
# 0        Online              C  10/8/2014  535113847  10/23/2014         934
# 1       Offline              L  2/22/2015  874708545   2/27/2015        4551
# 2       Offline              M  12/9/2015  854349935   1/18/2016        9986
# 3        Online              M  9/17/2014  892836844  10/12/2014        9118
# 4       Offline              H   2/4/2010  129280602    3/5/2010        5858
#
# ...

# %%
sns.set_theme(font='Times')
sns.set_style(style='whitegrid')

#plt.figure(figsize=(20,15))
#sns.countplot(data=data2,x='Region')

sns.countplot(data=data2,y='Region')
sns.set_context(context='poster')

sns.despine()
