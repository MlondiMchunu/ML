# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('bank-full.csv')

# %%
X,y =

# %%
# %matplotlib inline

# %%
hm = df.corr()
hm
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.097783 -0.009120 -0.004648  0.004760 -0.023758  0.001288
# balance   0.097783  1.000000  0.004503  0.021560 -0.014578  0.003435  0.016674
# day      -0.009120  0.004503  1.000000 -0.030206  0.162490 -0.093044 -0.051710
# duration -0.004648  0.021560 -0.030206  1.000000 -0.084570 -0.001565  0.001203
# campaign  0.004760 -0.014578  0.162490 -0.084570  1.000000 -0.088628 -0.032855
# pdays    -0.023758  0.003435 -0.093044 -0.001565 -0.088628  1.000000  0.454820
# previous  0.001288  0.016674 -0.051710  0.001203 -0.032855  0.454820  1.000000

# %%
sns.heatmap(data = hm,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
bp = (df['poutcome']== 'success') & (df['contact']== 'telephone')
df[bp]
# Out:
#        age            job   marital  education default  balance housing loan  \
# 24165   30         admin.   married  secondary      no      873     yes   no
# 24506   42     unemployed   married    unknown      no      970     yes   no
# 25962   34         admin.   married   tertiary      no      899     yes   no
# 26069   39     management  divorced   tertiary      no     4692     yes   no
# 27974   41  self-employed    single   tertiary      no     1616      no   no
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 45078   77        retired   married  secondary      no      820      no   no
# 45112   24        student    single  secondary      no     1234      no   no
# 45140   63   entrepreneur   married  secondary      no     3904      no   no
# 45141   77        unknown   married    unknown      no      397      no   no
# 45166   41     unemployed    single   tertiary      no       79      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 24165  telephone   12   nov       119         1    167         3  success
# 24506  telephone   17   nov       725         1    119        10  success
# 25962  telephone   19   nov       377         3      7         4  success
# 26069  telephone   19   nov       214         2    174         2  success
# 27974  telephone   28   jan       229         1    184         7  success
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 45078  telephone   21   oct       330         2    181         4  success
# 45112  telephone   26   oct       280         2     97         3  success
# 45140  telephone    8   nov       360         1     96         4  success
# 45141  telephone    8   nov       207         1    185         3  success
# 45166  telephone    9   nov       394         1    390         2  success
#
#       Target
# 24165     no
# 24506     no
# 25962     no
# 26069     no
# 27974     no
# ...      ...
# 45078    yes
# 45112     no
# 45140    yes
# 45141     no
# 45166    yes
#
# [114 rows x 17 columns]

# %%
plt.figure(figsize=(20,9))
sns.barplot(data=df[bp],x='age',y='balance')
# Out:
# <AxesSubplot:xlabel='age', ylabel='balance'>

# %%
th = df[bp].corr()
th
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.154193 -0.141156  0.092529 -0.264206  0.008086 -0.068263
# balance   0.154193  1.000000 -0.146543  0.005925 -0.030190 -0.082848  0.008049
# day      -0.141156 -0.146543  1.000000  0.098996 -0.016401 -0.049560  0.045631
# duration  0.092529  0.005925  0.098996  1.000000 -0.112783 -0.034918  0.018256
# campaign -0.264206 -0.030190 -0.016401 -0.112783  1.000000  0.033939  0.032193
# pdays     0.008086 -0.082848 -0.049560 -0.034918  0.033939  1.000000 -0.043977
# previous -0.068263  0.008049  0.045631  0.018256  0.032193 -0.043977  1.000000

# %%
sns.heatmap(data=th,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(th,bins=50)
# Out:
# /Users/mlondi/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
X_train,,X_test,y_test = l
